# %%
# %run ./util

# %%
import re
project_name = "omop-tables"
omop_version = "531"

from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("OMOP Tables to Delta") \
        .getOrCreate()

vocab_path = "dbfs:/FileStore/tables/vocabulary/"
output_path = f"/dbfs/{project_name}/{omop_version}/"

def sanitize_column_name(name):
    return re.sub(r'[ ,;{}()\n\t=]', '_', name)

def csv_to_delta(file_info):
    file_path = file_info.path
    file_name = file_info.name.split('.')[0]
    delta_path = f"{output_path}/{file_name}"

    df = spark.read.csv(file_path, header=True, inferSchema=True)

    for col in df.columns:
        df = df.withColumnRenamed(col, sanitize_column_name(col))

    df.write.format("delta").mode("overwrite").save(delta_path)
    print(f"Wrote {file_name} to {delta_path}")
    
files = dbutils.fs.ls(vocab_path)

for file in files:
    if file.name.endswith(".csv"):
        csv_to_delta(file)
# Out:
# Wrote CONCEPT to /dbfs/omop-tables/531//CONCEPT
# Wrote CONCEPT_ANCESTOR to /dbfs/omop-tables/531//CONCEPT_ANCESTOR
# Wrote CONCEPT_CLASS to /dbfs/omop-tables/531//CONCEPT_CLASS
# Wrote CONCEPT_CPT4 to /dbfs/omop-tables/531//CONCEPT_CPT4
# Wrote CONCEPT_RELATIONSHIP to /dbfs/omop-tables/531//CONCEPT_RELATIONSHIP
# Wrote CONCEPT_SYNONYM to /dbfs/omop-tables/531//CONCEPT_SYNONYM
# Wrote DOMAIN to /dbfs/omop-tables/531//DOMAIN
# Wrote DRUG_STRENGTH to /dbfs/omop-tables/531//DRUG_STRENGTH
# Wrote RELATIONSHIP to /dbfs/omop-tables/531//RELATIONSHIP
# Wrote VOCABULARY to /dbfs/omop-tables/531//VOCABULARY
# /Workspace/Users/s0382292@stanfordhealthcare.org

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Drop Vocabulary Tables") \
    .getOrCreate()

catalog = "ancillary_projects"
schema = "cdm_synthea10"

vocab_tables = [
    "CONCEPT",
    "CONCEPT_ANCESTOR",
    "CONCEPT_CLASS",
    "CONCEPT_CPT4",
    "CONCEPT_RELATIONSHIP",
    "CONCEPT_SYNONYM",
    "DOMAIN",
    "DRUG_STRENGTH",
    "RELATIONSHIP",
    "VOCABULARY"
]

for table in vocab_tables:
    table_name = f"{catalog}.{schema}.{table}"
    spark.sql(f"DROP TABLE IF EXISTS {table_name}")
    print(f"Dropped table {table_name}")
# Out:
# Dropped table ancillary_projects.cdm_synthea10.CONCEPT
# Dropped table ancillary_projects.cdm_synthea10.CONCEPT_ANCESTOR
# Dropped table ancillary_projects.cdm_synthea10.CONCEPT_CLASS
# Dropped table ancillary_projects.cdm_synthea10.CONCEPT_CPT4
# Dropped table ancillary_projects.cdm_synthea10.CONCEPT_RELATIONSHIP
# Dropped table ancillary_projects.cdm_synthea10.CONCEPT_SYNONYM
# Dropped table ancillary_projects.cdm_synthea10.DOMAIN
# Dropped table ancillary_projects.cdm_synthea10.DRUG_STRENGTH
# Dropped table ancillary_projects.cdm_synthea10.RELATIONSHIP
# Dropped table ancillary_projects.cdm_synthea10.VOCABULARY

# %%
import re
from pyspark.sql import SparkSession
from pyspark.sql.functions import split, col

project_name = "omop-tables"
omop_version = "531"

spark = SparkSession.builder \
    .appName("OMOP Tables to Delta") \
    .config("spark.databricks.delta.schema.autoMerge.enabled", "true") \
    .getOrCreate()

vocab_path = "dbfs:/FileStore/tables/vocabulary/"
catalog = "ancillary_projects"
schema = "cdm_synthea10"

def sanitize_column_name(name):
    return re.sub(r'[ ,;{}()\n\t=]', '_', name)

def csv_to_delta(file_info):
    file_path = file_info.path
    file_name = file_info.name.split('.')[0]
    table_name = f"{catalog}.{schema}.{file_name}"

    df = spark.read.csv(file_path, header=True, inferSchema=True, sep='\t', quote='"', escape='"')

    if df.columns[0] == "concept_id_concept_name_domain_id_vocabulary_id_concept_class_id_standard_concept_concept_code_valid_start_date_valid_end_date_invalid_reason":
        df = df.withColumn("raw_data", col(df.columns[0]))

        expected_columns = [
            "CONCEPT_ID", "CONCEPT_NAME", "DOMAIN_ID", "VOCABULARY_ID", "CONCEPT_CLASS_ID",
            "STANDARD_CONCEPT", "CONCEPT_CODE", "VALID_START_DATE", "VALID_END_DATE", "INVALID_REASON"
        ]

        df = df.withColumn("split_data", split(col("raw_data"), r'\t')).select(
            *[col("split_data")[i].alias(expected_columns[i]) for i in range(len(expected_columns))]
        ).drop("raw_data")

    for col_name in df.columns:
        df = df.withColumnRenamed(col_name, sanitize_column_name(col_name))

    df.write.format("delta") \
        .mode("overwrite") \
        .option("mergeSchema", "true") \
        .saveAsTable(table_name)
    print(f"Wrote {file_name} to {table_name}")

# List all files in the vocabulary path
files = dbutils.fs.ls(vocab_path)

# Process each CSV file
for file in files:
    if file.name.endswith(".csv"):
        csv_to_delta(file)
# Out:
# Wrote CONCEPT to ancillary_projects.cdm_synthea10.CONCEPT
# Wrote CONCEPT_ANCESTOR to ancillary_projects.cdm_synthea10.CONCEPT_ANCESTOR
# Wrote CONCEPT_CLASS to ancillary_projects.cdm_synthea10.CONCEPT_CLASS
# Wrote CONCEPT_CPT4 to ancillary_projects.cdm_synthea10.CONCEPT_CPT4
# Wrote CONCEPT_RELATIONSHIP to ancillary_projects.cdm_synthea10.CONCEPT_RELATIONSHIP
# Wrote CONCEPT_SYNONYM to ancillary_projects.cdm_synthea10.CONCEPT_SYNONYM
# Wrote DOMAIN to ancillary_projects.cdm_synthea10.DOMAIN
# Wrote DRUG_STRENGTH to ancillary_projects.cdm_synthea10.DRUG_STRENGTH
# Wrote RELATIONSHIP to ancillary_projects.cdm_synthea10.RELATIONSHIP
# Wrote VOCABULARY to ancillary_projects.cdm_synthea10.VOCABULARY

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
import os
import json
import re
from decimal import Decimal
from concurrent.futures import ThreadPoolExecutor, as_completed
from datetime import datetime, timedelta, tzinfo, date
import pytz
import collections
import logging

# %%
spark = SparkSession.builder \
    .appName("Extracting Patients Details") \
        .getOrCreate()

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %%
GENDER_LABEL = {
    "M": "primary",
    "W": "danger",
    "F": "danger"
}
GENDER_MAP = {
    "M": "M",
    "W": "F",
    "F": "F",
    "MALE": "M",
    "FEMALE": "F"
}

COLOR_MAP = {
    "Condition": "#4daf4a",
    "Drug": "#eb9adb",
    "Measurement": "#80b1d3",
    "Observation": "#ccffff",
    "Procedure": "#ff7f00"
}

MEASURE_FLAG_MAP = {
    "L": {
        "color": "#fb8072"
    },
    "H": {
        "color": "#fb8072"
    }
}
# Out:
# INFO:py4j.clientserver:Received command c on object id p0

# %%
_tz = pytz.timezone('US/Eastern')
_epoch = datetime(year=1970, month=1, day=1, tzinfo=_tz)
_day_seconds = 24 * 3600
_milli = 10**6

def _mktime(dt):
    td = dt - _epoch
    res = (td.microseconds + (td.seconds + td.days * _day_seconds) * _milli) / _milli
    return int(res - res % _day_seconds)

def to_time(date_str):
    return _mktime(datetime(year=int(date_str[0:4]), month=int(date_str[4:6]), day=int(date_str[6:8]), tzinfo=_tz))

def from_time(stamp):
    return datetime.fromtimestamp(stamp, _tz).strftime("%Y%m%d")

def next_day(stamp):
    return shift_days(stamp, 1)

def shift_days(stamp, days):
    return _mktime(_epoch + timedelta(days=days, seconds=stamp))

# %% [markdown]
# Imported Utilities functions from util.py notebook - Included Time Completed

# %%
import os
import json
import sys
import logging
from concurrent.futures import ThreadPoolExecutor, as_completed
from datetime import datetime
from decimal import Decimal
from pyspark.sql import SparkSession
from pyspark.sql.functions import col

# Initialize Spark session
spark = SparkSession.builder.appName("OMOPDataProcessing").getOrCreate()

# Setup logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

class OMOP:
    def __init__(self, catalog, schema, debug_output):
        self.catalog = catalog
        self.schema = schema
        self._parents = {}
        self._codes = {}
        self.debug_output = debug_output

    def _exec(self, query):
        df = spark.sql(query)
        return df.collect()

    def _exec_one(self, query):
        result = self._exec(query)
        if not result:
            raise ValueError(f"expected one result row got 0\n{query}\n")
        return result[0]

    def list_patients(self, patients, prefix="", limit=None, show_old_ids=False):
        limit_str = f" LIMIT {limit}" if limit else ""
        query = f"SELECT person_id, person_source_value FROM {self.catalog}.{self.schema}.person{limit_str}"
        results = self._exec(query)
        for r in results:
            patients.add(str(prefix) + (str(r['person_id']) if not show_old_ids else str(r['person_source_value']) + '.json'))

    def get_person_id(self, pid):
        query = f"SELECT person_id FROM {self.catalog}.{self.schema}.person WHERE person_source_value = '{pid}'"
        return str(self._exec_one(query)['person_id'])

    def add_info(self, obj, id, key, value, has_label=False, label=""):
        for info in obj["info"]:
            if info["id"] == id:
                if str(value) != str(info["value"]):
                    print(f'duplicate "{id}" new: {value} old: {info["value"]}', file=sys.stderr)
                return
        node = {"id": id, "name": key, "value": value}
        if has_label:
            node["label"] = label
        obj["info"].append(node)

    def get_info(self, pid, obj):
        query = f"""SELECT
             concept_name as gender_concept_name,
             person_source_value,
             year_of_birth
            FROM
             {self.catalog}.{self.schema}.person
            LEFT JOIN {self.catalog}.{self.schema}.concept ON (
             gender_concept_id = concept_id
            ) WHERE
             person_id = '{pid}'
        """
        result = self._exec_one(query)
        if result['person_source_value']:
            self.add_info(obj, 'id_alt', 'ID', str(result['person_source_value']) + ".json")
        self.add_info(obj, 'born', 'Born', int(result['year_of_birth']))
        gender = str(result['gender_concept_name'])
        self.add_info(obj, 'gender', 'Gender', GENDER_MAP.get(gender.upper(), 'U'), True, GENDER_LABEL.get(gender, 'U'))
        
    def to_time(self, value):
        return toTime(value.strftime("%Y%m%d"))

    def create_event(self, group, id, claim_id, has_result=False, result_flag="", result=""):
        res = {"id": id, "group": group}
        if claim_id is not None:
            res["row_id"] = claim_id
        if has_result:
            res["flag_value"] = result
            res["flag"] = result_flag
        return res

    def add_dict(self, dict, new_dict_entries, group, prefix, id, name, desc, code, unmapped):
        alt_hierarchies = f'{group}_{prefix}'
        if group not in dict:
            dict[group] = {}
            dict[group][""] = {
                "id": "",
                "name": group,
                "desc": group,
                "color": COLOR_MAP.get(group, "lightgray"),
                "parent": ""
            }
            if alt_hierarchies in self._codes:
                ah = {}
                if alt_hierarchies in self._parents:
                    ah = self._parents[alt_hierarchies]
                for key, value in self._codes[alt_hierarchies].items():
                    dict[group][key] = {
                        "id": key,
                        "name": value,
                        "desc": value,
                        "los": 0,
                        "parent": ah.get(key, "")
                    }
            if group == "Measurement":
                dict[group][""]["flags"] = MEASURE_FLAG_MAP
        g = dict[group]
        full_id = f'{prefix}{id}'
        if full_id not in g:
            res = {"id": id, "name": name, "desc": desc, "parent": ""}
            if unmapped:
                res["unmapped"] = True
            g[full_id] = res
            do_add = True
            if alt_hierarchies in self._parents:
                ah = self._parents[alt_hierarchies]
                if code in ah:
                    res["los"] = 0
                    res["parent"] = ah[code]
                    do_add = False
                else:
                    code = code.replace('.', '')
                    if code in ah:
                        res["parent"] = ah[code]
                        do_add = False
            if id != 0 and do_add:
                new_dict_entries.add(str(id))

    def get_dict_entry(self, dict, group, prefix, id):
        if group not in dict:
            return None
        full_id = f'{prefix}{id}'
        return dict[group].get(full_id, None)

    def update_hierarchies(self, dict, new_dict_entries):
        while new_dict_entries:
            query = """SELECT
                 c.concept_id as c_id,
                 c.domain_id as c_domain,
                 c.concept_name as c_name,
                 c.vocabulary_id as c_vocab,
                 c.concept_code as c_num,
                 ca.min_levels_of_separation as c_distance,
                 ca.descendant_concept_id as c_desc_id,
                 cc.domain_id as c_desc_domain,
                 cc.vocabulary_id as c_desc_vocab
                FROM
                 {catalog}.{schema}.concept_ancestor as ca
                LEFT JOIN {catalog}.{schema}.concept as c ON (
                 c.concept_id = ca.ancestor_concept_id
                ) LEFT JOIN {catalog}.{schema}.concept as cc ON (
                 cc.concept_id = ca.descendant_concept_id
                ) WHERE
                 ca.descendant_concept_id != 0
                 AND ca.ancestor_concept_id != 0
                 AND ca.descendant_concept_id IN ({id_list})
            """.format(catalog=self.catalog, schema=self.schema, id_list=','.join(sorted(list(new_dict_entries))))
            result = self._exec(query)
            new_dict_entries.clear()
            for row in result:
                parent_id = str(row['c_id'])
                parent_group = row['c_domain']
                parent_name = row['c_name']
                parent_vocab = row['c_vocab']
                parent_code = row['c_num']
                unmapped = False
                if parent_code == 0:
                    parent_code = row['c_orig']
                    unmapped = True
                parent_desc = f'{parent_name} ({parent_vocab} {parent_code})'
                self.add_dict(dict, new_dict_entries, parent_group, parent_vocab, parent_id, parent_name, parent_desc, parent_code, unmapped)
                dos = int(row['c_distance'])
                desc_id = str(row['c_desc_id'])
                desc_vocab = row['c_desc_vocab']
                desc_group = row['c_desc_domain']
                if desc_group != parent_group:
                    print(f"WARNING: intra group inheritance: {parent_group} << {desc_group}", file=sys.stderr)
                else:
                    desc_entry = self.get_dict_entry(dict, desc_group, desc_vocab, desc_id)
                    if desc_entry is not None and parent_id != desc_id and ('dos' not in desc_entry or desc_entry['dos'] > dos):
                        desc_entry['dos'] = dos
                        desc_entry['parent'] = f'{parent_vocab}{parent_id}'
            new_dict_entries.clear()

    def get_diagnoses(self, pid, obj, dict, new_dict_entries):
        query = f"""SELECT
            o.condition_occurrence_id as id_row,
            o.condition_start_date as date_start,
            o.condition_end_date as date_end,
            o.condition_concept_id as d_id,
            o.condition_source_value as d_orig,
            c.domain_id as d_domain,
            c.concept_name as d_name,
            c.vocabulary_id as d_vocab,
            c.concept_code as d_num
           FROM
            {self.catalog}.{self.schema}.condition_occurrence as o
           LEFT JOIN {self.catalog}.{self.schema}.concept as c ON (
            c.concept_id = o.condition_concept_id
           )
           WHERE
            o.person_id = '{pid}'
        """
        for row in self._exec(query):
            code = row['d_num']
            unmapped = False
            if code == 0:
                code = row['d_orig']
                unmapped = True
            id_row = f'c{row["id_row"]}'
            d_id = row['d_id']
            name = row['d_name']
            vocab = row['d_vocab']
            group = "Condition" if row['d_domain'] is None else row['d_domain']
            desc = f'{name} ({vocab} {code})'
            self.add_dict(dict, new_dict_entries, group, vocab, d_id, name, desc, code, unmapped)
            date_start = self.to_time(row['date_start'])
            date_end = self.to_time(row['date_end']) if row['date_end'] else date_start
            date_cur = date_start
            while date_cur <= date_end:
                event = self.create_event(group, f'{vocab}{d_id}', id_row)
                event['time'] = date_cur
                obj['events'].append(event)
                date_cur = nextDay(date_cur)

    def get_procedures(self, pid, obj, dict, new_dict_entries):
        query = f"""SELECT
            o.procedure_occurrence_id as id_row,
            o.procedure_date as p_date,
            o.procedure_concept_id as p_id,
            o.procedure_source_value as p_orig,
            c.domain_id as p_domain,
            c.concept_name as p_name,
            c.vocabulary_id as p_vocab,
            c.concept_code as p_num
           FROM
            {self.catalog}.{self.schema}.procedure_occurrence as o
           LEFT JOIN {self.catalog}.{self.schema}.concept as c ON (
            c.concept_id = o.procedure_concept_id
           )
           WHERE
            o.person_id = '{pid}'
        """
        for row in self._exec(query):
            code = row['p_num']
            unmapped = False
            if code == 0:
                code = row['p_orig']
                unmapped = True
            id_row = f'p{row["id_row"]}'
            d_id = row['p_id']
            name = row['p_name']
            vocab = row['p_vocab']
            group = "Procedure" if row['p_domain'] is None else row['p_domain']
            desc = f'{name} ({vocab} {code})'
            self.add_dict(dict, new_dict_entries, group, vocab, d_id, name, desc, code, unmapped)
            event = self.create_event(group, f'{vocab}{d_id}', id_row)
            event['time'] = self.to_time(row['p_date'])
            obj['events'].append(event)

    def get_observations_concept_valued(self, pid, obj, dict, new_dict_entries):
        query = f"""SELECT
            o.observation_id as id_row,
            o.observation_date as o_date,
            o.observation_concept_id as o_id,
            o.observation_source_value as o_orig,
            o.value_as_concept_id as o_val_concept,
            c_val.concept_name as o_val_concept_name,
            c.domain_id as o_domain,
            c.concept_name as o_name,
            c.vocabulary_id as o_vocab,
            c.concept_code as o_num
           FROM
            {self.catalog}.{self.schema}.observation as o
           LEFT JOIN {self.catalog}.{self.schema}.concept as c ON (
            c.concept_id = o.observation_concept_id
           )
           INNER JOIN {self.catalog}.{self.schema}.concept as c_val ON (
            c_val.concept_id = o.value_as_concept_id
           )
           WHERE
            o.person_id = '{pid}'
            AND o.value_as_concept_id IS NOT NULL
        """
        for row in self._exec(query):
            code = row['o_num']
            unmapped = False
            if code == 0:
                code = row['o_orig']
                unmapped = True
            id_row = f'p{row["id_row"]}'
            d_id = row['o_id']
            name = "unknown" if row['o_name'] is None else row['o_name']
            vocab = row['o_vocab']
            group = "Observation" if row['o_domain'] is None else row['o_domain']
            desc = f'{name} ({vocab} {code})'
            self.add_dict(dict, new_dict_entries, group, vocab, d_id, name, desc, code, unmapped)
            event = self.create_event(group, f'{vocab}{d_id}', id_row, True, "C", str(row['o_val_concept_name']))
            event['time'] = self.to_time(row['o_date'])
            obj['events'].append(event)

    def get_observations_string_valued(self, pid, obj, dict, new_dict_entries):
        query = f"""SELECT
            o.observation_id as id_row,
            o.observation_date as o_date,
            o.observation_concept_id as o_id,
            o.observation_source_value as o_orig,
            o.value_as_string as o_val_string,
            c.domain_id as o_domain,
            c.concept_name as o_name,
            c.vocabulary_id as o_vocab,
            c.concept_code as o_num
           FROM
            {self.catalog}.{self.schema}.observation as o
           LEFT JOIN {self.catalog}.{self.schema}.concept as c ON (
            c.concept_id = o.observation_concept_id
           )
           WHERE
            o.person_id = '{pid}'
            AND o.value_as_string IS NOT NULL
        """
        for row in self._exec(query):
            code = row['o_num']
            unmapped = False
            if code == 0:
                code = row['o_orig']
                unmapped = True
            id_row = f'p{row["id_row"]}'
            d_id = row['o_id']
            name = "unknown" if row['o_name'] is None else row['o_name']
            vocab = row['o_vocab']
            group = "Observation" if row['o_domain'] is None else row['o_domain']
            desc = f'{name} ({vocab} {code})'
            self.add_dict(dict, new_dict_entries, group, vocab, d_id, name, desc, code, unmapped)
            event = self.create_event(group, f'{vocab}{d_id}', id_row, True, "S", row['o_val_string'])
            event['time'] = self.to_time(row['o_date'])
            obj['events'].append(event)

    def get_observations_number_valued(self, pid, obj, dict, new_dict_entries):
        query = f"""SELECT
            o.observation_id as id_row,
            o.observation_date as o_date,
            o.observation_concept_id as o_id,
            o.observation_source_value as o_orig,
            o.value_as_number as o_val_number,
            c.domain_id as o_domain,
            c.concept_name as o_name,
            c.vocabulary_id as o_vocab,
            c.concept_code as o_num
           FROM
            {self.catalog}.{self.schema}.observation as o
           LEFT JOIN {self.catalog}.{self.schema}.concept as c ON (
            c.concept_id = o.observation_concept_id
           )
           WHERE
            o.person_id = '{pid}'
            AND o.value_as_number IS NOT NULL
        """
        for row in self._exec(query):
            code = row['o_num']
            unmapped = False
            if code == 0:
                code = row['o_orig']
                unmapped = True
            id_row = f'p{row["id_row"]}'
            d_id = row['o_id']
            name = "unknown" if row['o_name'] is None else row['o_name']
            vocab = row['o_vocab']
            group = "Observation" if row['o_domain'] is None else row['o_domain']
            desc = f'{name} ({vocab} {code})'
            self.add_dict(dict, new_dict_entries, group, vocab, d_id, name, desc, code, unmapped)
            event = self.create_event(group, f'{vocab}{d_id}', id_row, True, "N", str(row['o_val_number']))
            event['time'] = self.to_time(row['o_date'])
            obj['events'].append(event)

    def get_drugs(self, pid, obj, dict, new_dict_entries):
        query = f"""SELECT
            o.drug_exposure_id as id_row,
            o.drug_exposure_start_date as date_start,
            o.drug_exposure_end_date as date_end,
            o.drug_concept_id as m_id,
            o.drug_source_value as m_orig,
            c.domain_id as m_domain,
            c.concept_name as m_name,
            c.vocabulary_id as m_vocab,
            c.concept_code as m_num
           FROM
            {self.catalog}.{self.schema}.drug_exposure as o
           LEFT JOIN {self.catalog}.{self.schema}.concept as c ON (
            c.concept_id = o.drug_concept_id
           )
           WHERE
            o.person_id = '{pid}'
        """
        for row in self._exec(query):
            code = row['m_num']
            unmapped = False
            if code == 0:
                code = row['m_orig']
                unmapped = True
            id_row = f'm{row["id_row"]}'
            d_id = row['m_id']
            name = row['m_name']
            vocab = row['m_vocab']
            group = "Drug" if row['m_domain'] is None else row['m_domain']
            desc = f'{name} ({vocab} {code})'
            self.add_dict(dict, new_dict_entries, group, vocab, d_id, name, desc, code, unmapped)
            date_start = self.to_time(row['date_start'])
            date_end = self.to_time(row['date_end']) if row['date_end'] else date_start
            date_cur = date_start
            while date_cur <= date_end:
                event = self.create_event(group, f'{vocab}{d_id}', id_row)
                event['time'] = date_cur
                obj['events'].append(event)
                date_cur = nextDay(date_cur)

    def get_measurements(self, pid, obj, dict, new_dict_entries):
        query = f"""SELECT
            o.measurement_id as id_row,
            o.measurement_date as m_date,
            o.measurement_concept_id as m_id,
            o.measurement_source_value as m_orig,
            o.value_source_value as m_orig_value,
            o.value_as_number as m_value,
            o.range_low as m_low,
            o.range_high as m_high,
            c.domain_id as m_domain,
            c.concept_name as m_name,
            c.vocabulary_id as m_vocab,
            c.concept_code as m_num
           FROM
            {self.catalog}.{self.schema}.measurement as o
           LEFT JOIN {self.catalog}.{self.schema}.concept as c ON (
            c.concept_id = o.measurement_concept_id
           )
           WHERE
            o.person_id = '{pid}'
        """
        for row in self._exec(query):
            code = row['m_num']
            unmapped = False
            if code == 0:
                code = row['m_orig']
                unmapped = True
            id_row = f'l{row["id_row"]}'
            d_id = row['m_id']
            name = row['m_name']
            vocab = row['m_vocab']
            group = "Measurement" if row['m_domain'] is None else row['m_domain']
            lab_value = row['m_value']
            lab_low = row['m_low']
            lab_high = row['m_high']

            lab_value = float(lab_value) if lab_value is not None and isinstance(lab_value, (int, float, Decimal)) else float('-inf')
            lab_low = float(lab_low) if lab_low is not None and isinstance(lab_low, (int, float, Decimal)) else float('-inf')
            lab_high = float(lab_high) if lab_high is not None and isinstance(lab_high, (int, float, Decimal)) else float('inf')

            lab_flag = ""
            if lab_value is not None and lab_value != float('-inf'):
                if lab_value <= lab_low:
                    lab_flag = "L"
                elif lab_value >= lab_high:
                    lab_flag = "H"
            else:
                lab_value = "n/a"

            desc = f'{name} ({vocab} {code})'
            self.add_dict(dict, new_dict_entries, group, vocab, d_id, name, desc, code, unmapped)
            event = self.create_event(group, f'{vocab}{d_id}', id_row, True, lab_flag, str(lab_value))
            event['time'] = self.to_time(row['m_date'])
            obj['events'].append(event)

    def get_visits(self, pid, obj):
        classes = obj["classes"]
        if not classes:
            return
        query = f"""
            SELECT v.visit_start_date as date_start, v.visit_end_date as date_end, c.concept_name as c_name
            FROM {self.catalog}.{self.schema}.visit_occurrence as v
            LEFT JOIN {self.catalog}.{self.schema}.concept as c ON (v.visit_concept_id = c.concept_id)
            WHERE v.person_id = '{pid}' AND c.concept_name IN ({','.join([f"'{k}'" for k in classes.keys()])})
        """
        v_spans = obj["v_spans"]
        for row in self._exec(query):
            visit_name = str(row['c_name'])
            date_start_dt = self.to_time(row['date_start'])
            date_end_dt = self.to_time(row['date_end'])

            if date_start_dt is None:
                continue

            v_spans.append({"class": visit_name, "from": self.format_time(date_start_dt), "to": self.format_time(date_end_dt)})

    def get_patient(self, pid, dictionary, line_file, class_file):
        obj = {
            "info": [],
            "events": [],
            "h_bars": [],
            "v_bars": ["auto"],
            "v_spans": [],
            "classes": {}
        }
        new_dict_entries = set()
        add_files(obj, line_file, class_file)
        self.get_info(pid, obj)
        self.add_info(obj, "pid", "Patient", pid)
        self.get_diagnoses(pid, obj, dictionary, new_dict_entries)
        self.get_observations_concept_valued(pid, obj, dictionary, new_dict_entries)
        self.get_observations_string_valued(pid, obj, dictionary, new_dict_entries)
        self.get_observations_number_valued(pid, obj, dictionary, new_dict_entries)
        self.get_procedures(pid, obj, dictionary, new_dict_entries)
        self.get_drugs(pid, obj, dictionary, new_dict_entries)
        self.get_measurements(pid, obj, dictionary, new_dict_entries)
        self.get_visits(pid, obj)
        min_time = float('inf')
        max_time = float('-inf')
        for e in obj["events"]:
            time = e["time"]
            if time < min_time:
                min_time = time
            if time > max_time:
                max_time = time
        obj["start"] = min_time
        obj["end"] = max_time
        self.add_info(obj, "event_count", "Events", len(obj["events"]))
        self.update_hierarchies(dictionary, new_dict_entries)
        return obj

def generate_patient_files(catalog, schema, batch_size=10):
    settings = {
        'catalog': catalog,
        'schema': schema,
        'omop_use_alt_hierarchies': False,
        'use_cache': True,  # This line sets use_cache to False
        'ccs_diag': '/dbfs/omop-tables/531/ccs_diag.csv',
        'ccs_proc': '/dbfs/omop-tables/531/ccs_proc.csv',
    }

    omop = OMOP(settings['catalog'], settings['schema'], True)

    patients = set()
    patients_path = '/dbfs/omop-tables/531/patients.txt'
    if os.path.isfile(patients_path):
        with open(patients_path, 'r') as pf:
            patients = set(pf.read().splitlines())
    else:
        logger.info(f"File {patients_path} does not exist. Starting with an empty patients set.")

    omop.list_patients(patients, prefix="json/")
    save_patients(patients)
    use_cache = settings.get('use_cache', True)

    dictionary = {}
    dictionary_path = '/dbfs/omop-tables/531/json/dictionary.json'
    if os.path.isfile(dictionary_path):
        with open(dictionary_path, 'r') as df:
            dictionary = json.load(df)

    # Ensure the 'json' directory exists
    json_dir = '/dbfs/omop-tables/531/json'
    if not os.path.exists(json_dir):
        os.makedirs(json_dir)
        logger.info(f"Created directory: {json_dir}")
    else:
        logger.info(f"Directory already exists: {json_dir}")

    patient_list = list(patients)
    total_patients = len(patient_list)
    logger.info(f"Total patients to process: {total_patients}")

    def process_patient(patient):
        pid = patient.split('/')[-1].replace('.json', '')
        cache_file = os.path.join(json_dir, f"{pid}.json")
        
        if not os.path.isfile(cache_file) or not use_cache:
            patient_data = omop.get_patient(pid, dictionary, None, None)
            with open(cache_file, 'w') as cf:
                json.dump(patient_data, cf)
                logger.info(f"Created JSON file for patient {pid}: {cache_file}")
        
        return dictionary

    with ThreadPoolExecutor(max_workers=4) as executor:
        future_to_patient = {executor.submit(process_patient, patient): patient for patient in patient_list}
        for future in as_completed(future_to_patient):
            patient = future_to_patient[future]
            try:
                result = future.result()
                dictionary.update(result)
            except Exception as exc:
                logger.error(f'{patient} generated an exception: {exc}')

    with open(dictionary_path, 'w') as df:
        json.dump(dictionary, df)


    with ThreadPoolExecutor(max_workers=4) as executor:
        future_to_patient = {executor.submit(process_patient, patient): patient for patient in patient_list}
        for future in as_completed(future_to_patient):
            patient = future_to_patient[future]
            try:
                result = future.result()
                dictionary.update(result)
            except Exception as exc:
                logger.error(f'{patient} generated an exception: {exc}')

    with open(dictionary_path, 'w') as df:
        json.dump(dictionary, df)

def save_patients(patients):
    patients_path = '/dbfs/omop-tables/531/patients.txt'
    # Ensure the directory exists
    os.makedirs(os.path.dirname(patients_path), exist_ok=True)
    with open(patients_path, 'w') as pf:
        pf.write('\n'.join(sorted(list(patients))))
        pf.flush()

if __name__ == '__main__':
    catalog = 'ancillary_projects'
    schema = 'cdm_synthea10'
    generate_patient_files(catalog, schema, batch_size=10)
# Out:
# INFO:py4j.clientserver:Received command c on object id p0
# INFO:__main__:Directory already exists: /dbfs/omop-tables/531/json
# INFO:__main__:Total patients to process: 11535
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Spec Anatomic Site << Observation
# INFO:__main__:Created JSON file for patient 8257: /dbfs/omop-tables/531/json/8257.json
# WARNING: intra group inheritance: Device << Drug
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Condition << Observation
# WARNING: intra group inheritance: Device << Drug
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Device << Drug
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Condition << Observation
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Device << Drug
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Device << Drug
# WARNING: intra group inheritance: Device << Drug
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Device << Drug
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Device << Drug
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Procedure << Measurement
# INFO:__main__:Created JSON file for patient 83: /dbfs/omop-tables/531/json/83.json
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Observation << Procedure
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Procedure
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Observation << Procedure
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# INFO:__main__:Created JSON file for patient 8336: /dbfs/omop-tables/531/json/8336.json
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Condition
# INFO:__main__:Created JSON file for patient 4871: /dbfs/omop-tables/531/json/4871.json

# %% [markdown]
# No Util's functions - Time Component Removed

# %%
import os
import json
import sys
import logging
from concurrent.futures import ThreadPoolExecutor, as_completed
from datetime import datetime
from decimal import Decimal
from pyspark.sql import SparkSession
from pyspark.sql.functions import col

# Initialize Spark session
spark = SparkSession.builder.appName("OMOPDataProcessing").getOrCreate()

# Setup logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

class OMOP:
    def __init__(self, catalog, schema, debug_output):
        self.catalog = catalog
        self.schema = schema
        self._parents = {}
        self._codes = {}
        self.debug_output = debug_output

    def _exec(self, query):
        df = spark.sql(query)
        return df.collect()

    def _exec_one(self, query):
        result = self._exec(query)
        if not result:
            raise ValueError(f"expected one result row got 0\n{query}\n")
        return result[0]

    def list_patients(self, patients, prefix="", limit=None, show_old_ids=False):
        limit_str = f" LIMIT {limit}" if limit else ""
        query = f"SELECT person_id, person_source_value FROM {self.catalog}.{self.schema}.person{limit_str}"
        results = self._exec(query)
        for r in results:
            patients.add(str(prefix) + (str(r['person_id']) if not show_old_ids else str(r['person_source_value']) + '.json'))

    def get_person_id(self, pid):
        query = f"SELECT person_id FROM {self.catalog}.{self.schema}.person WHERE person_source_value = '{pid}'"
        return str(self._exec_one(query)['person_id'])

    def add_info(self, obj, id, key, value, has_label=False, label=""):
        for info in obj["info"]:
            if info["id"] == id:
                if str(value) != str(info["value"]):
                    print(f'duplicate "{id}" new: {value} old: {info["value"]}', file=sys.stderr)
                return
        node = {"id": id, "name": key, "value": value}
        if has_label:
            node["label"] = label
        obj["info"].append(node)

    def get_info(self, pid, obj):
        query = f"""SELECT
             concept_name as gender_concept_name,
             person_source_value,
             year_of_birth
            FROM
             {self.catalog}.{self.schema}.person
            LEFT JOIN {self.catalog}.{self.schema}.concept ON (
             gender_concept_id = concept_id
            ) WHERE
             person_id = '{pid}'
        """
        result = self._exec_one(query)
        if result['person_source_value']:
            self.add_info(obj, 'id_alt', 'ID', str(result['person_source_value']) + ".json")
        self.add_info(obj, 'born', 'Born', int(result['year_of_birth']))
        gender = str(result['gender_concept_name'])
        self.add_info(obj, 'gender', 'Gender', GENDER_MAP.get(gender.upper(), 'U'), True, GENDER_LABEL.get(gender, 'U'))
        
    # def to_time(self, value):
    #     if isinstance(value, datetime):
    #         return value.replace(tzinfo=None)
    #     elif isinstance(value, date):
    #         return datetime.combine(value, datetime.min.time()).replace(tzinfo=None)
    #     elif isinstance(value, str):
    #         return datetime.strptime(value, "%Y-%m-%d").replace(tzinfo=None)
    #     else:
    #         raise ValueError(f"Unsupported date format: {value}")


    def create_event(self, group, id, claim_id, has_result=False, result_flag="", result=""):
        res = {"id": id, "group": group}
        if claim_id is not None:
            res["row_id"] = claim_id
        if has_result:
            res["flag_value"] = result
            res["flag"] = result_flag
        return res

    def add_dict(self, dict, new_dict_entries, group, prefix, id, name, desc, code, unmapped):
        alt_hierarchies = f'{group}_{prefix}'
        if group not in dict:
            dict[group] = {}
            dict[group][""] = {
                "id": "",
                "name": group,
                "desc": group,
                "color": COLOR_MAP.get(group, "lightgray"),
                "parent": ""
            }
            if alt_hierarchies in self._codes:
                ah = {}
                if alt_hierarchies in self._parents:
                    ah = self._parents[alt_hierarchies]
                for key, value in self._codes[alt_hierarchies].items():
                    dict[group][key] = {
                        "id": key,
                        "name": value,
                        "desc": value,
                        "los": 0,
                        "parent": ah.get(key, "")
                    }
            if group == "Measurement":
                dict[group][""]["flags"] = MEASURE_FLAG_MAP
        g = dict[group]
        full_id = f'{prefix}{id}'
        if full_id not in g:
            res = {"id": id, "name": name, "desc": desc, "parent": ""}
            if unmapped:
                res["unmapped"] = True
            g[full_id] = res
            do_add = True
            if alt_hierarchies in self._parents:
                ah = self._parents[alt_hierarchies]
                if code in ah:
                    res["los"] = 0
                    res["parent"] = ah[code]
                    do_add = False
                else:
                    code = code.replace('.', '')
                    if code in ah:
                        res["parent"] = ah[code]
                        do_add = False
            if id != 0 and do_add:
                new_dict_entries.add(str(id))

    def get_dict_entry(self, dict, group, prefix, id):
        if group not in dict:
            return None
        full_id = f'{prefix}{id}'
        return dict[group].get(full_id, None)

    def update_hierarchies(self, dict, new_dict_entries):
        while new_dict_entries:
            query = """SELECT
                 c.concept_id as c_id,
                 c.domain_id as c_domain,
                 c.concept_name as c_name,
                 c.vocabulary_id as c_vocab,
                 c.concept_code as c_num,
                 ca.min_levels_of_separation as c_distance,
                 ca.descendant_concept_id as c_desc_id,
                 cc.domain_id as c_desc_domain,
                 cc.vocabulary_id as c_desc_vocab
                FROM
                 {catalog}.{schema}.concept_ancestor as ca
                LEFT JOIN {catalog}.{schema}.concept as c ON (
                 c.concept_id = ca.ancestor_concept_id
                ) LEFT JOIN {catalog}.{schema}.concept as cc ON (
                 cc.concept_id = ca.descendant_concept_id
                ) WHERE
                 ca.descendant_concept_id != 0
                 AND ca.ancestor_concept_id != 0
                 AND ca.descendant_concept_id IN ({id_list})
            """.format(catalog=self.catalog, schema=self.schema, id_list=','.join(sorted(list(new_dict_entries))))
            result = self._exec(query)
            new_dict_entries.clear()
            for row in result:
                parent_id = str(row['c_id'])
                parent_group = row['c_domain']
                parent_name = row['c_name']
                parent_vocab = row['c_vocab']
                parent_code = row['c_num']
                unmapped = False
                if parent_code == 0:
                    parent_code = row['c_orig']
                    unmapped = True
                parent_desc = f'{parent_name} ({parent_vocab} {parent_code})'
                self.add_dict(dict, new_dict_entries, parent_group, parent_vocab, parent_id, parent_name, parent_desc, parent_code, unmapped)
                dos = int(row['c_distance'])
                desc_id = str(row['c_desc_id'])
                desc_vocab = row['c_desc_vocab']
                desc_group = row['c_desc_domain']
                if desc_group != parent_group:
                    print(f"WARNING: intra group inheritance: {parent_group} << {desc_group}", file=sys.stderr)
                else:
                    desc_entry = self.get_dict_entry(dict, desc_group, desc_vocab, desc_id)
                    if desc_entry is not None and parent_id != desc_id and ('dos' not in desc_entry or desc_entry['dos'] > dos):
                        desc_entry['dos'] = dos
                        desc_entry['parent'] = f'{parent_vocab}{parent_id}'
            new_dict_entries.clear()

    def get_diagnoses(self, pid, obj, dict, new_dict_entries):
        query = f"""SELECT
            o.condition_occurrence_id as id_row,
            o.condition_start_date as date_start,
            o.condition_end_date as date_end,
            o.condition_concept_id as d_id,
            o.condition_source_value as d_orig,
            c.domain_id as d_domain,
            c.concept_name as d_name,
            c.vocabulary_id as d_vocab,
            c.concept_code as d_num
           FROM
            {self.catalog}.{self.schema}.condition_occurrence as o
           LEFT JOIN {self.catalog}.{self.schema}.concept as c ON (
            c.concept_id = o.condition_concept_id
           )
           WHERE
            o.person_id = '{pid}'
        """
        for row in self._exec(query):
            code = row['d_num']
            unmapped = False
            if code == 0:
                code = row['d_orig']
                unmapped = True
            id_row = f'c{row["id_row"]}'
            d_id = row['d_id']
            name = row['d_name']
            vocab = row['d_vocab']
            group = "Condition" if row['d_domain'] is None else row['d_domain']
            desc = f'{name} ({vocab} {code})'
            self.add_dict(dict, new_dict_entries, group, vocab, d_id, name, desc, code, unmapped)
            #date_start = self.to_time(row['date_start'])
            #date_end = self.to_time(row['date_end']) if row['date_end'] else date_start
            #date_cur = date_start
            #while date_cur <= date_end:
            event = self.create_event(group, f'{vocab}{d_id}', id_row)
                #event['time'] = date_cur
            obj['events'].append(event)
                #date_cur = date_cur + timedelta(days=1)

    def get_procedures(self, pid, obj, dict, new_dict_entries):
        query = f"""SELECT
            o.procedure_occurrence_id as id_row,
            o.procedure_date as p_date,
            o.procedure_concept_id as p_id,
            o.procedure_source_value as p_orig,
            c.domain_id as p_domain,
            c.concept_name as p_name,
            c.vocabulary_id as p_vocab,
            c.concept_code as p_num
           FROM
            {self.catalog}.{self.schema}.procedure_occurrence as o
           LEFT JOIN {self.catalog}.{self.schema}.concept as c ON (
            c.concept_id = o.procedure_concept_id
           )
           WHERE
            o.person_id = '{pid}'
        """
        for row in self._exec(query):
            code = row['p_num']
            unmapped = False
            if code == 0:
                code = row['p_orig']
                unmapped = True
            id_row = f'p{row["id_row"]}'
            d_id = row['p_id']
            name = row['p_name']
            vocab = row['p_vocab']
            group = "Procedure" if row['p_domain'] is None else row['p_domain']
            desc = f'{name} ({vocab} {code})'
            self.add_dict(dict, new_dict_entries, group, vocab, d_id, name, desc, code, unmapped)
            event = self.create_event(group, f'{vocab}{d_id}', id_row)
            #event['time'] = self.to_time(row['p_date'])
            obj['events'].append(event)

    def get_observations_concept_valued(self, pid, obj, dict, new_dict_entries):
        query = f"""SELECT
            o.observation_id as id_row,
            o.observation_date as o_date,
            o.observation_concept_id as o_id,
            o.observation_source_value as o_orig,
            o.value_as_concept_id as o_val_concept,
            c_val.concept_name as o_val_concept_name,
            c.domain_id as o_domain,
            c.concept_name as o_name,
            c.vocabulary_id as o_vocab,
            c.concept_code as o_num
           FROM
            {self.catalog}.{self.schema}.observation as o
           LEFT JOIN {self.catalog}.{self.schema}.concept as c ON (
            c.concept_id = o.observation_concept_id
           )
           INNER JOIN {self.catalog}.{self.schema}.concept as c_val ON (
            c_val.concept_id = o.value_as_concept_id
           )
           WHERE
            o.person_id = '{pid}'
            AND o.value_as_concept_id IS NOT NULL
        """
        for row in self._exec(query):
            code = row['o_num']
            unmapped = False
            if code == 0:
                code = row['o_orig']
                unmapped = True
            id_row = f'p{row["id_row"]}'
            d_id = row['o_id']
            name = "unknown" if row['o_name'] is None else row['o_name']
            vocab = row['o_vocab']
            group = "Observation" if row['o_domain'] is None else row['o_domain']
            desc = f'{name} ({vocab} {code})'
            self.add_dict(dict, new_dict_entries, group, vocab, d_id, name, desc, code, unmapped)
            event = self.create_event(group, f'{vocab}{d_id}', id_row, True, "C", str(row['o_val_concept_name']))
            #event['time'] = self.to_time(row['o_date'])
            obj['events'].append(event)

    def get_observations_string_valued(self, pid, obj, dict, new_dict_entries):
        query = f"""SELECT
            o.observation_id as id_row,
            o.observation_date as o_date,
            o.observation_concept_id as o_id,
            o.observation_source_value as o_orig,
            o.value_as_string as o_val_string,
            c.domain_id as o_domain,
            c.concept_name as o_name,
            c.vocabulary_id as o_vocab,
            c.concept_code as o_num
           FROM
            {self.catalog}.{self.schema}.observation as o
           LEFT JOIN {self.catalog}.{self.schema}.concept as c ON (
            c.concept_id = o.observation_concept_id
           )
           WHERE
            o.person_id = '{pid}'
            AND o.value_as_string IS NOT NULL
        """
        for row in self._exec(query):
            code = row['o_num']
            unmapped = False
            if code == 0:
                code = row['o_orig']
                unmapped = True
            id_row = f'p{row["id_row"]}'
            d_id = row['o_id']
            name = "unknown" if row['o_name'] is None else row['o_name']
            vocab = row['o_vocab']
            group = "Observation" if row['o_domain'] is None else row['o_domain']
            desc = f'{name} ({vocab} {code})'
            self.add_dict(dict, new_dict_entries, group, vocab, d_id, name, desc, code, unmapped)
            event = self.create_event(group, f'{vocab}{d_id}', id_row, True, "S", row['o_val_string'])
            #event['time'] = self.to_time(row['o_date'])
            obj['events'].append(event)

    def get_observations_number_valued(self, pid, obj, dict, new_dict_entries):
        query = f"""SELECT
            o.observation_id as id_row,
            o.observation_date as o_date,
            o.observation_concept_id as o_id,
            o.observation_source_value as o_orig,
            o.value_as_number as o_val_number,
            c.domain_id as o_domain,
            c.concept_name as o_name,
            c.vocabulary_id as o_vocab,
            c.concept_code as o_num
           FROM
            {self.catalog}.{self.schema}.observation as o
           LEFT JOIN {self.catalog}.{self.schema}.concept as c ON (
            c.concept_id = o.observation_concept_id
           )
           WHERE
            o.person_id = '{pid}'
            AND o.value_as_number IS NOT NULL
        """
        for row in self._exec(query):
            code = row['o_num']
            unmapped = False
            if code == 0:
                code = row['o_orig']
                unmapped = True
            id_row = f'p{row["id_row"]}'
            d_id = row['o_id']
            name = "unknown" if row['o_name'] is None else row['o_name']
            vocab = row['o_vocab']
            group = "Observation" if row['o_domain'] is None else row['o_domain']
            desc = f'{name} ({vocab} {code})'
            self.add_dict(dict, new_dict_entries, group, vocab, d_id, name, desc, code, unmapped)
            event = self.create_event(group, f'{vocab}{d_id}', id_row, True, "N", str(row['o_val_number']))
            #event['time'] = self.to_time(row['o_date'])
            obj['events'].append(event)

    def get_drugs(self, pid, obj, dict, new_dict_entries):
        query = f"""SELECT
            o.drug_exposure_id as id_row,
            o.drug_exposure_start_date as date_start,
            o.drug_exposure_end_date as date_end,
            o.drug_concept_id as m_id,
            o.drug_source_value as m_orig,
            c.domain_id as m_domain,
            c.concept_name as m_name,
            c.vocabulary_id as m_vocab,
            c.concept_code as m_num
           FROM
            {self.catalog}.{self.schema}.drug_exposure as o
           LEFT JOIN {self.catalog}.{self.schema}.concept as c ON (
            c.concept_id = o.drug_concept_id
           )
           WHERE
            o.person_id = '{pid}'
        """
        for row in self._exec(query):
            code = row['m_num']
            unmapped = False
            if code == 0:
                code = row['m_orig']
                unmapped = True
            id_row = f'm{row["id_row"]}'
            d_id = row['m_id']
            name = row['m_name']
            vocab = row['m_vocab']
            group = "Drug" if row['m_domain'] is None else row['m_domain']
            desc = f'{name} ({vocab} {code})'
            self.add_dict(dict, new_dict_entries, group, vocab, d_id, name, desc, code, unmapped)
            #date_start = self.to_time(row['date_start'])
            #date_end = self.to_time(row['date_end']) if row['date_end'] else date_start
            #date_cur = date_start
            #while date_cur <= date_end:
            event = self.create_event(group, f'{vocab}{d_id}', id_row)
                #event['time'] = date_cur
            obj['events'].append(event)
                #date_cur = date_cur + timedelta(days=1)

    def get_measurements(self, pid, obj, dict, new_dict_entries):
        query = f"""SELECT
            o.measurement_id as id_row,
            o.measurement_date as m_date,
            o.measurement_concept_id as m_id,
            o.measurement_source_value as m_orig,
            o.value_source_value as m_orig_value,
            o.value_as_number as m_value,
            o.range_low as m_low,
            o.range_high as m_high,
            c.domain_id as m_domain,
            c.concept_name as m_name,
            c.vocabulary_id as m_vocab,
            c.concept_code as m_num
           FROM
            {self.catalog}.{self.schema}.measurement as o
           LEFT JOIN {self.catalog}.{self.schema}.concept as c ON (
            c.concept_id = o.measurement_concept_id
           )
           WHERE
            o.person_id = '{pid}'
        """
        for row in self._exec(query):
            code = row['m_num']
            unmapped = False
            if code == 0:
                code = row['m_orig']
                unmapped = True
            id_row = f'l{row["id_row"]}'
            d_id = row['m_id']
            name = row['m_name']
            vocab = row['m_vocab']
            group = "Measurement" if row['m_domain'] is None else row['m_domain']
            lab_value = row['m_value']
            lab_low = row['m_low']
            lab_high = row['m_high']

            lab_value = float(lab_value) if lab_value is not None and isinstance(lab_value, (int, float, Decimal)) else float('-inf')
            lab_low = float(lab_low) if lab_low is not None and isinstance(lab_low, (int, float, Decimal)) else float('-inf')
            lab_high = float(lab_high) if lab_high is not None and isinstance(lab_high, (int, float, Decimal)) else float('inf')

            lab_flag = ""
            if lab_value is not None and lab_value != float('-inf'):
                if lab_value <= lab_low:
                    lab_flag = "L"
                elif lab_value >= lab_high:
                    lab_flag = "H"
            else:
                lab_value = "n/a"

            desc = f'{name} ({vocab} {code})'
            self.add_dict(dict, new_dict_entries, group, vocab, d_id, name, desc, code, unmapped)
            event = self.create_event(group, f'{vocab}{d_id}', id_row, True, lab_flag, str(lab_value))
            #event['time'] = self.to_time(row['m_date'])
            obj['events'].append(event)

    def get_visits(self, pid, obj):
        classes = obj["classes"]
        if not classes:
            return
        query = f"""
            SELECT v.visit_start_date as date_start, v.visit_end_date as date_end, c.concept_name as c_name
            FROM {self.catalog}.{self.schema}.visit_occurrence as v
            LEFT JOIN {self.catalog}.{self.schema}.concept as c ON (v.visit_concept_id = c.concept_id)
            WHERE v.person_id = '{pid}' AND c.concept_name IN ({','.join([f"'{k}'" for k in classes.keys()])})
        """
        v_spans = obj["v_spans"]
        for row in self._exec(query):
            visit_name = str(row['c_name'])
            #date_start_dt = self.to_time(row['date_start'])
            #date_end_dt = self.to_time(row['date_end'])

            # if date_start_dt is None:
            #     continue

            v_spans.append({"class": visit_name}) #"from": self.format_time(date_start_dt), "to": self.format_time(date_end_dt)})

    def get_patient(self, pid, dictionary, line_file, class_file):
        obj = {
            "info": [],
            "events": [],
            "h_bars": [],
            "v_bars": ["auto"],
            "v_spans": [],
            "classes": {}
        }
        new_dict_entries = set()
        self.get_info(pid, obj)
        self.add_info(obj, "pid", "Patient", pid)
        self.get_diagnoses(pid, obj, dictionary, new_dict_entries)
        self.get_observations_concept_valued(pid, obj, dictionary, new_dict_entries)
        self.get_observations_string_valued(pid, obj, dictionary, new_dict_entries)
        self.get_observations_number_valued(pid, obj, dictionary, new_dict_entries)
        self.get_procedures(pid, obj, dictionary, new_dict_entries)
        self.get_drugs(pid, obj, dictionary, new_dict_entries)
        self.get_measurements(pid, obj, dictionary, new_dict_entries)
        self.get_visits(pid, obj)
        # min_time = float('inf')
        # max_time = float('-inf')
        # for e in obj["events"]:
        #     time = e["time"]
        #     if time < min_time:
        #         min_time = time
        #     if time > max_time:
        #         max_time = time
        # obj["start"] = min_time
        # obj["end"] = max_time
        self.add_info(obj, "event_count", "Events", len(obj["events"]))
        self.update_hierarchies(dictionary, new_dict_entries)
        return obj

def generate_patient_files(catalog, schema, batch_size=10):
    settings = {
        'catalog': catalog,
        'schema': schema,
        'omop_use_alt_hierarchies': False,
        'use_cache': True,  # This line sets use_cache to False
        'ccs_diag': '/dbfs/omop-tables/531/ccs_diag.csv',
        'ccs_proc': '/dbfs/omop-tables/531/ccs_proc.csv',
    }

    omop = OMOP(settings['catalog'], settings['schema'], True)

    patients = set()
    patients_path = '/dbfs/omop-tables/531/patients.txt'
    if os.path.isfile(patients_path):
        with open(patients_path, 'r') as pf:
            patients = set(pf.read().splitlines())
    else:
        logger.info(f"File {patients_path} does not exist. Starting with an empty patients set.")

    omop.list_patients(patients, prefix="json/")
    save_patients(patients)
    use_cache = settings.get('use_cache', True)

    dictionary = {}
    dictionary_path = '/dbfs/omop-tables/531/json/dictionary.json'
    if os.path.isfile(dictionary_path):
        with open(dictionary_path, 'r') as df:
            dictionary = json.load(df)

    # Ensure the 'json' directory exists
    json_dir = '/dbfs/omop-tables/531/json'
    if not os.path.exists(json_dir):
        os.makedirs(json_dir)
        logger.info(f"Created directory: {json_dir}")
    else:
        logger.info(f"Directory already exists: {json_dir}")

    patient_list = list(patients)
    total_patients = len(patient_list)
    logger.info(f"Total patients to process: {total_patients}")

    def process_patient(patient):
        pid = patient.split('/')[-1].replace('.json', '')
        cache_file = os.path.join(json_dir, f"{pid}.json")
        
        if not os.path.isfile(cache_file) or not use_cache:
            patient_data = omop.get_patient(pid, dictionary, None, None)
            with open(cache_file, 'w') as cf:
                json.dump(patient_data, cf)
                logger.info(f"Created JSON file for patient {pid}: {cache_file}")
        
        return dictionary

    with ThreadPoolExecutor(max_workers=4) as executor:
        future_to_patient = {executor.submit(process_patient, patient): patient for patient in patient_list}
        for future in as_completed(future_to_patient):
            patient = future_to_patient[future]
            try:
                result = future.result()
                dictionary.update(result)
            except Exception as exc:
                logger.error(f'{patient} generated an exception: {exc}')

    with open(dictionary_path, 'w') as df:
        json.dump(dictionary, df)


    with ThreadPoolExecutor(max_workers=4) as executor:
        future_to_patient = {executor.submit(process_patient, patient): patient for patient in patient_list}
        for future in as_completed(future_to_patient):
            patient = future_to_patient[future]
            try:
                result = future.result()
                dictionary.update(result)
            except Exception as exc:
                logger.error(f'{patient} generated an exception: {exc}')

    with open(dictionary_path, 'w') as df:
        json.dump(dictionary, df)

def save_patients(patients):
    patients_path = '/dbfs/omop-tables/531/patients.txt'
    # Ensure the directory exists
    os.makedirs(os.path.dirname(patients_path), exist_ok=True)
    with open(patients_path, 'w') as pf:
        pf.write('\n'.join(sorted(list(patients))))
        pf.flush()

if __name__ == '__main__':
    catalog = 'ancillary_projects'
    schema = 'cdm_synthea10'
    generate_patient_files(catalog, schema, batch_size=10)
# Out:
# INFO:__main__:Directory already exists: /dbfs/omop-tables/531/json
# INFO:__main__:Total patients to process: 11535
# WARNING: intra group inheritance: Device << Drug
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Device << Drug
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Device << Drug
# WARNING: intra group inheritance: Device << Drug
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Device << Drug
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Device << Drug
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Procedure << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Condition << Observation
# WARNING: intra group inheritance: Condition << Observation
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Observation << Measurement
# INFO:__main__:Created JSON file for patient 10902: /dbfs/omop-tables/531/json/10902.json
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Condition
# WARNING: intra group inheritance: Measurement << Condition
# WARNING: intra group inheritance: Measurement << Condition
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Procedure
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Condition
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Observation << Measurement
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra group inheritance: Measurement << Observation
# WARNING: intra gr
#
# *** WARNING: max output size exceeded, skipping output. ***
#
# ient 3101: /dbfs/omop-tables/531/json/3101.json
# INFO:__main__:Created JSON file for patient 2442: /dbfs/omop-tables/531/json/2442.json
# INFO:__main__:Created JSON file for patient 2506: /dbfs/omop-tables/531/json/2506.json
# INFO:__main__:Created JSON file for patient 4588: /dbfs/omop-tables/531/json/4588.json
# INFO:__main__:Created JSON file for patient 6960: /dbfs/omop-tables/531/json/6960.json
# INFO:__main__:Created JSON file for patient 862: /dbfs/omop-tables/531/json/862.json
# INFO:__main__:Created JSON file for patient 3407: /dbfs/omop-tables/531/json/3407.json
# INFO:__main__:Created JSON file for patient 9691: /dbfs/omop-tables/531/json/9691.json
# INFO:__main__:Created JSON file for patient 1643: /dbfs/omop-tables/531/json/1643.json
# INFO:__main__:Created JSON file for patient 4877: /dbfs/omop-tables/531/json/4877.json
# INFO:__main__:Created JSON file for patient 749: /dbfs/omop-tables/531/json/749.json
# INFO:__main__:Created JSON file for patient 7790: /dbfs/omop-tables/531/json/7790.json
# INFO:__main__:Created JSON file for patient 7302: /dbfs/omop-tables/531/json/7302.json
# INFO:__main__:Created JSON file for patient 10715: /dbfs/omop-tables/531/json/10715.json
# INFO:__main__:Created JSON file for patient 470: /dbfs/omop-tables/531/json/470.json
# INFO:__main__:Created JSON file for patient 5988: /dbfs/omop-tables/531/json/5988.json
# INFO:__main__:Created JSON file for patient 9104: /dbfs/omop-tables/531/json/9104.json
# INFO:__main__:Created JSON file for patient 8537: /dbfs/omop-tables/531/json/8537.json
# INFO:__main__:Created JSON file for patient 1378: /dbfs/omop-tables/531/json/1378.json
# INFO:__main__:Created JSON file for patient 11146: /dbfs/omop-tables/531/json/11146.json
# INFO:__main__:Created JSON file for patient 3285: /dbfs/omop-tables/531/json/3285.json
# INFO:__main__:Created JSON file for patient 9182: /dbfs/omop-tables/531/json/9182.json
# INFO:__main__:Created JSON file for patient 7437: /dbfs/omop-tables/531/json/7437.json
# INFO:__main__:Created JSON file for patient 1912: /dbfs/omop-tables/531/json/1912.json
# INFO:__main__:Created JSON file for patient 2379: /dbfs/omop-tables/531/json/2379.json
# INFO:__main__:Created JSON file for patient 10153: /dbfs/omop-tables/531/json/10153.json
# INFO:__main__:Created JSON file for patient 6640: /dbfs/omop-tables/531/json/6640.json
# INFO:__main__:Created JSON file for patient 5715: /dbfs/omop-tables/531/json/5715.json
# INFO:__main__:Created JSON file for patient 4346: /dbfs/omop-tables/531/json/4346.json
# INFO:__main__:Created JSON file for patient 5297: /dbfs/omop-tables/531/json/5297.json
# INFO:__main__:Created JSON file for patient 609: /dbfs/omop-tables/531/json/609.json
# INFO:__main__:Created JSON file for patient 6111: /dbfs/omop-tables/531/json/6111.json
# INFO:__main__:Created JSON file for patient 797: /dbfs/omop-tables/531/json/797.json
# INFO:__main__:Created JSON file for patient 8414: /dbfs/omop-tables/531/json/8414.json
# INFO:__main__:Created JSON file for patient 1136: /dbfs/omop-tables/531/json/1136.json
# INFO:__main__:Created JSON file for patient 4707: /dbfs/omop-tables/531/json/4707.json
# INFO:__main__:Created JSON file for patient 9893: /dbfs/omop-tables/531/json/9893.json
# INFO:__main__:Created JSON file for patient 6914: /dbfs/omop-tables/531/json/6914.json
# INFO:__main__:Created JSON file for patient 6528: /dbfs/omop-tables/531/json/6528.json
# INFO:__main__:Created JSON file for patient 350: /dbfs/omop-tables/531/json/350.json
# INFO:__main__:Created JSON file for patient 6136: /dbfs/omop-tables/531/json/6136.json
# INFO:__main__:Created JSON file for patient 10417: /dbfs/omop-tables/531/json/10417.json
# INFO:__main__:Created JSON file for patient 3074: /dbfs/omop-tables/531/json/3074.json
# INFO:__main__:Created JSON file for patient 9577: /dbfs/omop-tables/531/json/9577.json
# INFO:__main__:Created JSON file for patient 9574: /dbfs/omop-tables/531/json/9574.json
# INFO:__main__:Created JSON file for patient 4714: /dbfs/omop-tables/531/json/4714.json
# INFO:__main__:Created JSON file for patient 2436: /dbfs/omop-tables/531/json/2436.json
# INFO:__main__:Created JSON file for patient 4779: /dbfs/omop-tables/531/json/4779.json
# INFO:__main__:Created JSON file for patient 734: /dbfs/omop-tables/531/json/734.json
# INFO:__main__:Created JSON file for patient 5986: /dbfs/omop-tables/531/json/5986.json
# INFO:__main__:Created JSON file for patient 9858: /dbfs/omop-tables/531/json/9858.json
# INFO:__main__:Created JSON file for patient 3047: /dbfs/omop-tables/531/json/3047.json
# INFO:__main__:Created JSON file for patient 6201: /dbfs/omop-tables/531/json/6201.json
# INFO:__main__:Created JSON file for patient 5714: /dbfs/omop-tables/531/json/5714.json
# INFO:__main__:Created JSON file for patient 8494: /dbfs/omop-tables/531/json/8494.json
# INFO:__main__:Created JSON file for patient 5461: /dbfs/omop-tables/531/json/5461.json
# INFO:__main__:Created JSON file for patient 11107: /dbfs/omop-tables/531/json/11107.json
# INFO:__main__:Created JSON file for patient 9117: /dbfs/omop-tables/531/json/9117.json
# INFO:__main__:Created JSON file for patient 7554: /dbfs/omop-tables/531/json/7554.json
# INFO:__main__:Created JSON file for patient 2039: /dbfs/omop-tables/531/json/2039.json
# INFO:__main__:Created JSON file for patient 10527: /dbfs/omop-tables/531/json/10527.json
# INFO:__main__:Created JSON file for patient 7229: /dbfs/omop-tables/531/json/7229.json
# INFO:__main__:Created JSON file for patient 7422: /dbfs/omop-tables/531/json/7422.json
# INFO:__main__:Created JSON file for patient 990: /dbfs/omop-tables/531/json/990.json
# INFO:__main__:Created JSON file for patient 3401: /dbfs/omop-tables/531/json/3401.json
# INFO:__main__:Created JSON file for patient 6886: /dbfs/omop-tables/531/json/6886.json
# INFO:__main__:Created JSON file for patient 9912: /dbfs/omop-tables/531/json/9912.json
# INFO:__main__:Created JSON file for patient 7108: /dbfs/omop-tables/531/json/7108.json
# INFO:__main__:Created JSON file for patient 7179: /dbfs/omop-tables/531/json/7179.json
# INFO:__main__:Created JSON file for patient 6605: /dbfs/omop-tables/531/json/6605.json
# INFO:__main__:Created JSON file for patient 1961: /dbfs/omop-tables/531/json/1961.json
# INFO:__main__:Created JSON file for patient 5222: /dbfs/omop-tables/531/json/5222.json
# INFO:__main__:Created JSON file for patient 10782: /dbfs/omop-tables/531/json/10782.json
# INFO:__main__:Created JSON file for patient 3748: /dbfs/omop-tables/531/json/3748.json
# INFO:__main__:Created JSON file for patient 4362: /dbfs/omop-tables/531/json/4362.json
# INFO:__main__:Created JSON file for patient 8114: /dbfs/omop-tables/531/json/8114.json
# INFO:__main__:Created JSON file for patient 390: /dbfs/omop-tables/531/json/390.json
# INFO:__main__:Created JSON file for patient 4789: /dbfs/omop-tables/531/json/4789.json
# INFO:__main__:Created JSON file for patient 10735: /dbfs/omop-tables/531/json/10735.json
# INFO:__main__:Created JSON file for patient 3591: /dbfs/omop-tables/531/json/3591.json
# INFO:__main__:Created JSON file for patient 10934: /dbfs/omop-tables/531/json/10934.json
# INFO:__main__:Created JSON file for patient 5370: /dbfs/omop-tables/531/json/5370.json
# INFO:__main__:Created JSON file for patient 6431: /dbfs/omop-tables/531/json/6431.json
# INFO:__main__:Created JSON file for patient 3417: /dbfs/omop-tables/531/json/3417.json
# INFO:__main__:Created JSON file for patient 8943: /dbfs/omop-tables/531/json/8943.json
# INFO:__main__:Created JSON file for patient 8235: /dbfs/omop-tables/531/json/8235.json
# INFO:__main__:Created JSON file for patient 8979: /dbfs/omop-tables/531/json/8979.json
# INFO:__main__:Created JSON file for patient 9416: /dbfs/omop-tables/531/json/9416.json
# INFO:__main__:Created JSON file for patient 2906: /dbfs/omop-tables/531/json/2906.json
# INFO:__main__:Created JSON file for patient 7763: /dbfs/omop-tables/531/json/7763.json
# INFO:__main__:Created JSON file for patient 3472: /dbfs/omop-tables/531/json/3472.json
# INFO:__main__:Created JSON file for patient 373: /dbfs/omop-tables/531/json/373.json
# INFO:__main__:Created JSON file for patient 7157: /dbfs/omop-tables/531/json/7157.json
# INFO:__main__:Created JSON file for patient 2063: /dbfs/omop-tables/531/json/2063.json
# INFO:__main__:Created JSON file for patient 8121: /dbfs/omop-tables/531/json/8121.json
# INFO:__main__:Created JSON file for patient 7305: /dbfs/omop-tables/531/json/7305.json
# INFO:__main__:Created JSON file for patient 4201: /dbfs/omop-tables/531/json/4201.json
# INFO:__main__:Created JSON file for patient 476: /dbfs/omop-tables/531/json/476.json
# INFO:__main__:Created JSON file for patient 6437: /dbfs/omop-tables/531/json/6437.json
# INFO:__main__:Created JSON file for patient 10290: /dbfs/omop-tables/531/json/10290.json
# INFO:__main__:Created JSON file for patient 2484: /dbfs/omop-tables/531/json/2484.json
# INFO:__main__:Created JSON file for patient 5162: /dbfs/omop-tables/531/json/5162.json
# INFO:__main__:Created JSON file for patient 5357: /dbfs/omop-tables/531/json/5357.json
# INFO:__main__:Created JSON file for patient 10719: /dbfs/omop-tables/531/json/10719.json
# INFO:__main__:Created JSON file for patient 8217: /dbfs/omop-tables/531/json/8217.json
# INFO:__main__:Created JSON file for patient 6409: /dbfs/omop-tables/531/json/6409.json
# INFO:__main__:Created JSON file for patient 4605: /dbfs/omop-tables/531/json/4605.json
# INFO:__main__:Created JSON file for patient 8545: /dbfs/omop-tables/531/json/8545.json
# INFO:__main__:Created JSON file for patient 9480: /dbfs/omop-tables/531/json/9480.json
# INFO:__main__:Created JSON file for patient 11011: /dbfs/omop-tables/531/json/11011.json
# INFO:__main__:Created JSON file for patient 64: /dbfs/omop-tables/531/json/64.json
# INFO:__main__:Created JSON file for patient 7277: /dbfs/omop-tables/531/json/7277.json
# INFO:__main__:Created JSON file for patient 6935: /dbfs/omop-tables/531/json/6935.json
# INFO:__main__:Created JSON file for patient 9070: /dbfs/omop-tables/531/json/9070.json
# INFO:__main__:Created JSON file for patient 9921: /dbfs/omop-tables/531/json/9921.json
# INFO:__main__:Created JSON file for patient 9938: /dbfs/omop-tables/531/json/9938.json
# INFO:__main__:Created JSON file for patient 3746: /dbfs/omop-tables/531/json/3746.json
# INFO:__main__:Created JSON file for patient 6228: /dbfs/omop-tables/531/json/6228.json
# INFO:__main__:Created JSON file for patient 1294: /dbfs/omop-tables/531/json/1294.json
# INFO:__main__:Created JSON file for patient 5083: /dbfs/omop-tables/531/json/5083.json
# INFO:__main__:Created JSON file for patient 10133: /dbfs/omop-tables/531/json/10133.json
# INFO:__main__:Created JSON file for patient 4293: /dbfs/omop-tables/531/json/4293.json
# INFO:__main__:Created JSON file for patient 11476: /dbfs/omop-tables/531/json/11476.json
# INFO:__main__:Created JSON file for patient 3656: /dbfs/omop-tables/531/json/3656.json
# INFO:__main__:Created JSON file for patient 732: /dbfs/omop-tables/531/json/732.json
# INFO:__main__:Created JSON file for patient 6903: /dbfs/omop-tables/531/json/6903.json
# INFO:__main__:Created JSON file for patient 6128: /dbfs/omop-tables/531/json/6128.json
# INFO:__main__:Created JSON file for patient 10796: /dbfs/omop-tables/531/json/10796.json
# INFO:__main__:Created JSON file for patient 2363: /dbfs/omop-tables/531/json/2363.json
# INFO:__main__:Created JSON file for patient 4042: /dbfs/omop-tables/531/json/4042.json
# INFO:__main__:Created JSON file for patient 4858: /dbfs/omop-tables/531/json/4858.json
# INFO:__main__:Created JSON file for patient 134: /dbfs/omop-tables/531/json/134.json
# INFO:__main__:Created JSON file for patient 7201: /dbfs/omop-tables/531/json/7201.json
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Condition
# WARNING: intra group inheritance: Observation << Condition
# INFO:__main__:Created JSON file for patient 10933: /dbfs/omop-tables/531/json/10933.json
# INFO:__main__:Created JSON file for patient 6557: /dbfs/omop-tables/531/json/6557.json
# INFO:__main__:Created JSON file for patient 7709: /dbfs/omop-tables/531/json/7709.json
# INFO:__main__:Created JSON file for patient 842: /dbfs/omop-tables/531/json/842.json
# INFO:__main__:Created JSON file for patient 10955: /dbfs/omop-tables/531/json/10955.json
# INFO:__main__:Created JSON file for patient 8307: /dbfs/omop-tables/531/json/8307.json
# INFO:__main__:Created JSON file for patient 2073: /dbfs/omop-tables/531/json/2073.json
# INFO:__main__:Created JSON file for patient 2365: /dbfs/omop-tables/531/json/2365.json
# INFO:__main__:Created JSON file for patient 2086: /dbfs/omop-tables/531/json/2086.json
# INFO:__main__:Created JSON file for patient 7479: /dbfs/omop-tables/531/json/7479.json
# INFO:__main__:Created JSON file for patient 8590: /dbfs/omop-tables/531/json/8590.json
# INFO:__main__:Created JSON file for patient 11064: /dbfs/omop-tables/531/json/11064.json
# INFO:__main__:Created JSON file for patient 2485: /dbfs/omop-tables/531/json/2485.json
# INFO:__main__:Created JSON file for patient 595: /dbfs/omop-tables/531/json/595.json
# INFO:__main__:Created JSON file for patient 10705: /dbfs/omop-tables/531/json/10705.json
# INFO:__main__:Created JSON file for patient 5609: /dbfs/omop-tables/531/json/5609.json
# INFO:__main__:Created JSON file for patient 7089: /dbfs/omop-tables/531/json/7089.json
# INFO:__main__:Created JSON file for patient 8071: /dbfs/omop-tables/531/json/8071.json
# INFO:__main__:Created JSON file for patient 11492: /dbfs/omop-tables/531/json/11492.json
# INFO:__main__:Created JSON file for patient 5531: /dbfs/omop-tables/531/json/5531.json
# INFO:__main__:Created JSON file for patient 7164: /dbfs/omop-tables/531/json/7164.json
# INFO:__main__:Created JSON file for patient 1921: /dbfs/omop-tables/531/json/1921.json
# INFO:__main__:Created JSON file for patient 9421: /dbfs/omop-tables/531/json/9421.json
# INFO:__main__:Created JSON file for patient 4377: /dbfs/omop-tables/531/json/4377.json
# INFO:__main__:Created JSON file for patient 6498: /dbfs/omop-tables/531/json/6498.json
# INFO:__main__:Created JSON file for patient 4581: /dbfs/omop-tables/531/json/4581.json
# INFO:__main__:Created JSON file for patient 4471: /dbfs/omop-tables/531/json/4471.json
# INFO:__main__:Created JSON file for patient 2322: /dbfs/omop-tables/531/json/2322.json
# INFO:__main__:Created JSON file for patient 736: /dbfs/omop-tables/531/json/736.json
# INFO:__main__:Created JSON file for patient 3219: /dbfs/omop-tables/531/json/3219.json
# INFO:__main__:Created JSON file for patient 3514: /dbfs/omop-tables/531/json/3514.json
# INFO:__main__:Created JSON file for patient 9881: /dbfs/omop-tables/531/json/9881.json
# INFO:__main__:Created JSON file for patient 10119: /dbfs/omop-tables/531/json/10119.json
# INFO:__main__:Created JSON file for patient 6602: /dbfs/omop-tables/531/json/6602.json
# INFO:__main__:Created JSON file for patient 11221: /dbfs/omop-tables/531/json/11221.json
# INFO:__main__:Created JSON file for patient 1596: /dbfs/omop-tables/531/json/1596.json
# INFO:__main__:Created JSON file for patient 8851: /dbfs/omop-tables/531/json/8851.json
# INFO:__main__:Created JSON file for patient 4564: /dbfs/omop-tables/531/json/4564.json
# INFO:__main__:Created JSON file for patient 6141: /dbfs/omop-tables/531/json/6141.json
# INFO:__main__:Created JSON file for patient 9051: /dbfs/omop-tables/531/json/9051.json
# INFO:__main__:Created JSON file for patient 1081: /dbfs/omop-tables/531/json/1081.json
# INFO:__main__:Created JSON file for patient 971: /dbfs/omop-tables/531/json/971.json
# INFO:__main__:Created JSON file for patient 5049: /dbfs/omop-tables/531/json/5049.json
# INFO:__main__:Created JSON file for patient 11008: /dbfs/omop-tables/531/json/11008.json
# INFO:__main__:Created JSON file for patient 4451: /dbfs/omop-tables/531/json/4451.json
# INFO:__main__:Created JSON file for patient 1067: /dbfs/omop-tables/531/json/1067.json
# INFO:__main__:Created JSON file for patient 4402: /dbfs/omop-tables/531/json/4402.json
# INFO:__main__:Created JSON file for patient 4969: /dbfs/omop-tables/531/json/4969.json
# INFO:__main__:Created JSON file for patient 2674: /dbfs/omop-tables/531/json/2674.json
# INFO:__main__:Created JSON file for patient 9688: /dbfs/omop-tables/531/json/9688.json
# INFO:__main__:Created JSON file for patient 10702: /dbfs/omop-tables/531/json/10702.json
# INFO:__main__:Created JSON file for patient 4695: /dbfs/omop-tables/531/json/4695.json
# INFO:__main__:Created JSON file for patient 3476: /dbfs/omop-tables/531/json/3476.json
# INFO:__main__:Created JSON file for patient 10218: /dbfs/omop-tables/531/json/10218.json
# INFO:__main__:Created JSON file for patient 1935: /dbfs/omop-tables/531/json/1935.json
# INFO:__main__:Created JSON file for patient 52: /dbfs/omop-tables/531/json/52.json
# INFO:__main__:Created JSON file for patient 9441: /dbfs/omop-tables/531/json/9441.json
# INFO:__main__:Created JSON file for patient 563: /dbfs/omop-tables/531/json/563.json
# INFO:__main__:Created JSON file for patient 4073: /dbfs/omop-tables/531/json/4073.json
# INFO:__main__:Created JSON file for patient 1593: /dbfs/omop-tables/531/json/1593.json
# INFO:__main__:Created JSON file for patient 10739: /dbfs/omop-tables/531/json/10739.json
# INFO:__main__:Created JSON file for patient 7487: /dbfs/omop-tables/531/json/7487.json
# INFO:__main__:Created JSON file for patient 9020: /dbfs/omop-tables/531/json/9020.json
# INFO:__main__:Created JSON file for patient 7876: /dbfs/omop-tables/531/json/7876.json
# INFO:__main__:Created JSON file for patient 6007: /dbfs/omop-tables/531/json/6007.json
# INFO:__main__:Created JSON file for patient 10225: /dbfs/omop-tables/531/json/10225.json
# INFO:__main__:Created JSON file for patient 3673: /dbfs/omop-tables/531/json/3673.json
# INFO:__main__:Created JSON file for patient 3026: /dbfs/omop-tables/531/json/3026.json
# INFO:__main__:Created JSON file for patient 3297: /dbfs/omop-tables/531/json/3297.json
# INFO:__main__:Created JSON file for patient 9876: /dbfs/omop-tables/531/json/9876.json
# INFO:__main__:Created JSON file for patient 5125: /dbfs/omop-tables/531/json/5125.json
# INFO:__main__:Created JSON file for patient 2610: /dbfs/omop-tables/531/json/2610.json
# INFO:__main__:Created JSON file for patient 5799: /dbfs/omop-tables/531/json/5799.json
# INFO:__main__:Created JSON file for patient 2764: /dbfs/omop-tables/531/json/2764.json
# INFO:__main__:Created JSON file for patient 5130: /dbfs/omop-tables/531/json/5130.json
# INFO:__main__:Created JSON file for patient 8160: /dbfs/omop-tables/531/json/8160.json
# INFO:__main__:Created JSON file for patient 9529: /dbfs/omop-tables/531/json/9529.json
# INFO:__main__:Created JSON file for patient 261: /dbfs/omop-tables/531/json/261.json
# INFO:__main__:Created JSON file for patient 1273: /dbfs/omop-tables/531/json/1273.json
# INFO:__main__:Created JSON file for patient 542: /dbfs/omop-tables/531/json/542.json
# INFO:__main__:Created JSON file for patient 3602: /dbfs/omop-tables/531/json/3602.json
# INFO:__main__:Created JSON file for patient 825: /dbfs/omop-tables/531/json/825.json
# INFO:__main__:Created JSON file for patient 8787: /dbfs/omop-tables/531/json/8787.json
# INFO:__main__:Created JSON file for patient 8156: /dbfs/omop-tables/531/json/8156.json
# INFO:__main__:Created JSON file for patient 10663: /dbfs/omop-tables/531/json/10663.json
# INFO:__main__:Created JSON file for patient 9674: /dbfs/omop-tables/531/json/9674.json
# INFO:__main__:Created JSON file for patient 1562: /dbfs/omop-tables/531/json/1562.json
# INFO:__main__:Created JSON file for patient 8173: /dbfs/omop-tables/531/json/8173.json
# INFO:__main__:Created JSON file for patient 2218: /dbfs/omop-tables/531/json/2218.json
# INFO:__main__:Created JSON file for patient 1905: /dbfs/omop-tables/531/json/1905.json
# INFO:__main__:Created JSON file for patient 5996: /dbfs/omop-tables/531/json/5996.json
# INFO:__main__:Created JSON file for patient 9258: /dbfs/omop-tables/531/json/9258.json
# INFO:__main__:Created JSON file for patient 5942: /dbfs/omop-tables/531/json/5942.json
# INFO:__main__:Created JSON file for patient 8475: /dbfs/omop-tables/531/json/8475.json
# INFO:__main__:Created JSON file for patient 3633: /dbfs/omop-tables/531/json/3633.json
# INFO:__main__:Created JSON file for patient 6256: /dbfs/omop-tables/531/json/6256.json
# INFO:__main__:Created JSON file for patient 3726: /dbfs/omop-tables/531/json/3726.json
# INFO:__main__:Created JSON file for patient 9944: /dbfs/omop-tables/531/json/9944.json
# INFO:__main__:Created JSON file for patient 1956: /dbfs/omop-tables/531/json/1956.json
# INFO:__main__:Created JSON file for patient 7787: /dbfs/omop-tables/531/json/7787.json
# INFO:__main__:Created JSON file for patient 8973: /dbfs/omop-tables/531/json/8973.json
# INFO:__main__:Created JSON file for patient 2892: /dbfs/omop-tables/531/json/2892.json
# INFO:__main__:Created JSON file for patient 5949: /dbfs/omop-tables/531/json/5949.json
# INFO:__main__:Created JSON file for patient 7281: /dbfs/omop-tables/531/json/7281.json
# INFO:__main__:Created JSON file for patient 488: /dbfs/omop-tables/531/json/488.json
# INFO:__main__:Created JSON file for patient 8335: /dbfs/omop-tables/531/json/8335.json
# INFO:__main__:Created JSON file for patient 8504: /dbfs/omop-tables/531/json/8504.json
# INFO:__main__:Created JSON file for patient 10830: /dbfs/omop-tables/531/json/10830.json
# INFO:__main__:Created JSON file for patient 7525: /dbfs/omop-tables/531/json/7525.json
# INFO:__main__:Created JSON file for patient 8098: /dbfs/omop-tables/531/json/8098.json
# INFO:__main__:Created JSON file for patient 9077: /dbfs/omop-tables/531/json/9077.json
# INFO:__main__:Created JSON file for patient 7788: /dbfs/omop-tables/531/json/7788.json
# INFO:__main__:Created JSON file for patient 10862: /dbfs/omop-tables/531/json/10862.json
# INFO:__main__:Created JSON file for patient 2792: /dbfs/omop-tables/531/json/2792.json
# INFO:__main__:Created JSON file for patient 6714: /dbfs/omop-tables/531/json/6714.json
# INFO:__main__:Created JSON file for patient 698: /dbfs/omop-tables/531/json/698.json
# INFO:__main__:Created JSON file for patient 2637: /dbfs/omop-tables/531/json/2637.json
# INFO:__main__:Created JSON file for patient 6868: /dbfs/omop-tables/531/json/6868.json
# INFO:__main__:Created JSON file for patient 11369: /dbfs/omop-tables/531/json/11369.json
# INFO:__main__:Created JSON file for patient 9373: /dbfs/omop-tables/531/json/9373.json
# INFO:__main__:Created JSON file for patient 11378: /dbfs/omop-tables/531/json/11378.json
# WARNING: intra group inheritance: Observation << Condition
# INFO:__main__:Created JSON file for patient 11342: /dbfs/omop-tables/531/json/11342.json
# INFO:__main__:Created JSON file for patient 10234: /dbfs/omop-tables/531/json/10234.json
# INFO:__main__:Created JSON file for patient 8447: /dbfs/omop-tables/531/json/8447.json
# INFO:__main__:Created JSON file for patient 899: /dbfs/omop-tables/531/json/899.json
# INFO:__main__:Created JSON file for patient 6088: /dbfs/omop-tables/531/json/6088.json
# INFO:__main__:Created JSON file for patient 2275: /dbfs/omop-tables/531/json/2275.json
# INFO:__main__:Created JSON file for patient 8092: /dbfs/omop-tables/531/json/8092.json
# INFO:__main__:Created JSON file for patient 2094: /dbfs/omop-tables/531/json/2094.json
# INFO:__main__:Created JSON file for patient 8736: /dbfs/omop-tables/531/json/8736.json
# INFO:__main__:Created JSON file for patient 9302: /dbfs/omop-tables/531/json/9302.json
# INFO:__main__:Created JSON file for patient 69: /dbfs/omop-tables/531/json/69.json
# INFO:__main__:Created JSON file for patient 9857: /dbfs/omop-tables/531/json/9857.json
# INFO:__main__:Created JSON file for patient 4423: /dbfs/omop-tables/531/json/4423.json
# INFO:__main__:Created JSON file for patient 1222: /dbfs/omop-tables/531/json/1222.json
# INFO:__main__:Created JSON file for patient 4502: /dbfs/omop-tables/531/json/4502.json
# INFO:__main__:Created JSON file for patient 10586: /dbfs/omop-tables/531/json/10586.json
# INFO:__main__:Created JSON file for patient 2422: /dbfs/omop-tables/531/json/2422.json
# INFO:__main__:Created JSON file for patient 214: /dbfs/omop-tables/531/json/214.json
# INFO:__main__:Created JSON file for patient 4999: /dbfs/omop-tables/531/json/4999.json
# INFO:__main__:Created JSON file for patient 4648: /dbfs/omop-tables/531/json/4648.json
# INFO:__main__:Created JSON file for patient 7321: /dbfs/omop-tables/531/json/7321.json
# INFO:__main__:Created JSON file for patient 5750: /dbfs/omop-tables/531/json/5750.json
# INFO:__main__:Created JSON file for patient 2382: /dbfs/omop-tables/531/json/2382.json
# INFO:__main__:Created JSON file for patient 6634: /dbfs/omop-tables/531/json/6634.json
# INFO:__main__:Created JSON file for patient 7732: /dbfs/omop-tables/531/json/7732.json
# INFO:__main__:Created JSON file for patient 2777: /dbfs/omop-tables/531/json/2777.json
# INFO:__main__:Created JSON file for patient 246: /dbfs/omop-tables/531/json/246.json
# INFO:__main__:Created JSON file for patient 4827: /dbfs/omop-tables/531/json/4827.json
# INFO:__main__:Created JSON file for patient 11387: /dbfs/omop-tables/531/json/11387.json
# INFO:__main__:Created JSON file for patient 1971: /dbfs/omop-tables/531/json/1971.json
# INFO:__main__:Created JSON file for patient 6652: /dbfs/omop-tables/531/json/6652.json

# %%
contents = dbutils.fs.head("dbfs:/omop-tables/531/json/4871.json")
# Out:
# [Truncated to first 65536 bytes]

# %%
display(contents)
# Out:
# '{"info": [{"id": "id_alt", "name": "ID", "value": "6b433a25-fd39-83f1-d0c6-f00d7779c915.json"}, {"id": "born", "name": "Born", "value": 1979}, {"id": "gender", "name": "Gender", "value": "F", "label": "U"}, {"id": "pid", "name": "Patient", "value": "4871"}, {"id": "event_count", "name": "Events", "value": 2725}], "events": [{"id": "SNOMED43530622", "group": "Condition", "row_id": "c43156", "time": 1391558400}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1414022400}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1414108800}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1414195200}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1414281600}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1414368000}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1414454400}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1414540800}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1414627200}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1414713600}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1414800000}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1414886400}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1414972800}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1415059200}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1415145600}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1415232000}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1415318400}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1415404800}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1415491200}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1415577600}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1415664000}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1415750400}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1415836800}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1415923200}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1416009600}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1416096000}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1416182400}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1416268800}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1416355200}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1416441600}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1416528000}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1416614400}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1416700800}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1416787200}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1416873600}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1416960000}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1417046400}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1417132800}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1417219200}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1417305600}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1417392000}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1417478400}, {"id": "SNOMED75053", "group": "Condition", "row_id": "c43161", "time": 1417564800}, {"id": "SNOMED7 ...
